# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_normal_1 = pd.read_csv('./medical_checkpoint/train_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1.csv') 
plt.plot(train_normal_1['epoch'], train_normal_1['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Training Accuracy phase1')
plt.show()

train_normal_2 = pd.read_csv('./medical_checkpoint/train_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2.csv') 
plt.plot(train_normal_2['epoch'], train_normal_2['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Training Accuracy phase2')
plt.show()

# %%
plt.plot(train_normal_1['epoch'], train_normal_1['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Training loss phase1')
plt.show()

plt.plot(train_normal_2['epoch'], train_normal_2['total_loss'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Training loss phase2')
plt.show()

# %%
test_normal_1 = pd.read_csv('./medical_checkpoint/test_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1.csv') 
plt.plot(test_normal_1['epoch'], test_normal_1['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('test Accuracy phase`')
plt.show()


test_normal_2 = pd.read_csv('./medical_checkpoint/test_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2.csv') 
plt.plot(test_normal_2['epoch'], test_normal_2['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('test Accuracy phase2')
plt.show()

# %%
plt.plot(test_normal_1['epoch'], test_normal_1['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('test loss phase1')
plt.show()

plt.plot(test_normal_2['epoch'], test_normal_2['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('test loss phase2')
plt.show()

# %%
train_normal_1 = pd.read_csv('./medical_checkpoint/verifier_train_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1.csv') 
plt.plot(train_normal_1['epoch'], train_normal_1['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('verifier Training Accuracy phase1')
plt.show()

train_normal_2 = pd.read_csv('./medical_checkpoint/verifier_train_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2.csv') 
plt.plot(train_normal_2['epoch'], train_normal_2['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('verifier Training Accuracy phase2')
plt.show()

# %%
plt.plot(train_normal_1['epoch'], train_normal_1['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('verifier Training loss phase1')
plt.show()

plt.plot(train_normal_2['epoch'], train_normal_2['total_loss'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('verifier Training loss phase2')
plt.show()

# %%
test_normal_1 = pd.read_csv('./medical_checkpoint/verifier_test_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1.csv') 
plt.plot(test_normal_1['epoch'], test_normal_1['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('verifier test Accuracy phase`')
plt.show()


test_normal_2 = pd.read_csv('./medical_checkpoint/verifier_test_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2.csv') 
plt.plot(test_normal_2['epoch'], test_normal_2['acc'], 'r')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('verifier test Accuracy phase2')
plt.show()

# %%
plt.plot(test_normal_1['epoch'], test_normal_1['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('verifier test loss phase1')
plt.show()

plt.plot(test_normal_2['epoch'], test_normal_2['total_loss'], 'r')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('verifier test loss phase2')
plt.show()

# %%
test_normal_1 = pd.read_csv('./medical_checkpoint/generations/3_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1_model.pth/log_file.csv')
test_normal_1.keys()
# plt.plot(test_normal_1['iteration'], test_normal_1['l'], 'r')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.title('verifier test Accuracy phase`')
# plt.show()


# test_normal_2 = pd.read_csv('./medical_checkpoint/verifier_test_log_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2.csv') 
# plt.plot(test_normal_2['epoch'], test_normal_2['acc'], 'r')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.title('verifier test Accuracy phase2')
# plt.show()
# Out:
# Index(['iteration', '            total loss',
#        '            loss batch normalization', '            loss variation_l2',
#        '            loss variation_l1', '            loss l2 on images',
#        '            Cross Entropy', '            Verifier Acc',
#        '            learning rate'],
#       dtype='object')

# %%
plt.plot(test_normal_1['iteration'], test_normal_1['            total loss'], 'r',
        test_normal_1['iteration'], test_normal_1['            loss batch normalization'], 'b',
        test_normal_1['iteration'], test_normal_1['            loss variation_l2'], 'g',
         test_normal_1['iteration'], test_normal_1['            loss l2 on images'], 'y',
        test_normal_1['iteration'], test_normal_1['            Cross Entropy'], 'purple')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation all losses phase1')
plt.show()

plt.plot(test_normal_1['iteration'], test_normal_1['            total loss'], 'r',)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation total loss phase1')
plt.show()



plt.plot(test_normal_1['iteration'], test_normal_1['            loss batch normalization'], 'b',)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss batch normalization phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            loss variation_l2'], 'g')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss variation_l2 phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            loss l2 on images'], 'y')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss l2 on images phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            Cross Entropy'], 'purple')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation Cross Entropy loss phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            Verifier Acc'], 'r')
plt.ylabel('Verifier Acc')
plt.xlabel('epoch')
plt.title('generation Verifier Acc phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            learning rate'], 'r')
plt.ylabel('lr rate')
plt.xlabel('epoch')
plt.title('generation learning rate phase1')
plt.show()

# %%
test_normal_1 = pd.read_csv('./medical_checkpoint/generations/3_seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2_model.pth/log_file.csv')

plt.plot(test_normal_1['iteration'], test_normal_1['            total loss'], 'r',
        test_normal_1['iteration'], test_normal_1['            loss batch normalization'], 'b',
        test_normal_1['iteration'], test_normal_1['            loss variation_l2'], 'g',
         test_normal_1['iteration'], test_normal_1['            loss l2 on images'], 'y',
        test_normal_1['iteration'], test_normal_1['            Cross Entropy'], 'purple')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation all losses phase1')
plt.show()

plt.plot(test_normal_1['iteration'], test_normal_1['            total loss'], 'r',)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation total loss phase1')
plt.show()

plt.plot(test_normal_1['iteration'], test_normal_1['            loss batch normalization'], 'b',)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss batch normalization phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            loss variation_l2'], 'g')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss variation_l2 phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            loss l2 on images'], 'y')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation loss l2 on images phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            Cross Entropy'], 'purple')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('generation Cross Entropy loss phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            Verifier Acc'], 'r')
plt.ylabel('Verifier Acc')
plt.xlabel('epoch')
plt.title('generation Verifier Acc phase1')
plt.show()


plt.plot(test_normal_1['iteration'], test_normal_1['            learning rate'], 'r')
plt.ylabel('lr rate')
plt.xlabel('epoch')
plt.title('generation learning rate phase1')
plt.show()

# %%
import pickle
cm_name = './checkpoint/seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_1_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[344.  16.]
#  [ 16. 379.]]

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(x[0], index = [1,2],
                  columns = [1,2])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
import pickle
cm_name = './checkpoint/seed_1993_rs_ratio_0.0_class_incremental_MR_LFAD_cosine_nb_cl_fg_2_nb_cl_1_nb_protos_20_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[250.   5. 105.]
#  [  3. 356.  36.]
#  [ 33.  36. 350.]]

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

df_cm = pd.DataFrame(x[0], index = [1,2,3],
                  columns = [1,2,3])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_run_0_iteration_1_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[344.  16.]
#  [ 22. 373.]]

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/no_sampler/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[  0.   0. 360.]
#  [  0.  72. 323.]
#  [  0.   0. 419.]]

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/paper_1/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[203.   2. 155.]
#  [  5. 317.  73.]
#  [  2.   5. 412.]]

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/paper_2/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_bsg_40_lrg_0.05_rfg_0.002_tv_l2g_0.01_l2g_0.01_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[275.   0.  85.]
#  [ 21. 103. 271.]
#  [ 76.   0. 343.]]

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/vanilla/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_3_nb_cl_1_lr_0.01_bs_40_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)

# %%
print(x[0])
# Out:
# [[323.  16.  21.]
#  [ 19. 371.   5.]
#  [  7.  12. 400.]]

# %%
import pickle
cm_name = './sweep_checkpoint/sweep_phase1_training/paper_2/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_bsg_40_lrg_0.05_rfg_0.002_tv_l2g_0.01_l2g_0.01_run_0_iteration_2_confusion_matrix.pth'
with open(cm_name, 'rb') as f:
    x = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-676cc2425fb5> in <module>
#       1 import pickle
#       2 cm_name = './sweep_checkpoint/sweep_phase1_training/paper_2/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_bsg_40_lrg_0.05_rfg_0.002_tv_l2g_0.01_l2g_0.01_run_0_iteration_2_confusion_matrix.pth'
# ----> 3 with open(cm_name, 'rb') as f:
#       4     x = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sweep_checkpoint/sweep_phase1_training/paper_2/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_bsg_40_lrg_0.05_rfg_0.002_tv_l2g_0.01_l2g_0.01_run_0_iteration_2_confusion_matrix.pth'

# %%
print(x[0])
# Out:
# [[  2.   0. 358.]
#  [  0. 224. 171.]
#  [  0.   0. 419.]]

# %%
generated_batch_add='./sweep_checkpoint/generations/sweep_phase1_training/class_incremental_MR_LFAD_cosine_small_nb_cl_fg_2_nb_cl_1_lr_0.01_bs_40_bsg_40_lrg_0.05_rfg_0.002_tv_l2g_0.01_l2g_0.01_gerated_data_run_0_iteration_1.pkl'


with open(generated_batch_add,'rb') as f:
    X_protoset_cumuls = pickle.load(f)

# %%
print(len(X_protoset_cumuls))
# Out:
# 7

# %%
print(X_protoset_cumuls[0].shape)
# Out:
# torch.Size([40, 1, 224, 224])

# %%
import torchvision.utils as vutils
place = './sweep_checkpoint/generations/sweep_phase1_training/here_check'
vutils.save_image((X_protoset_cumuls[0][0]-X_protoset_cumuls[0][0].min())*255,'{}/output_1{:05d}.png'.format(place,1),
                  normalize=False, scale_each=False, nrow=int(10))

# %%
import numpy as np
print(X_protoset_cumuls[0].min(),X_protoset_cumuls[0].max())
# Out:
# tensor(-0.0386) tensor(0.0211)

# %%
print(X_protoset_cumuls[0][0][0][0][0])
# Out:
# tensor(-0.0001)

# %%
np.where(X_protoset_cumuls[0][0][0] == -0.0386)
# Out:
# (array([], dtype=int64), array([], dtype=int64))
